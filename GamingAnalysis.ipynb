# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('GamesData.csv')

# %%
df.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  critic_score  total_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North           9.4        20.32
# 1     PS4   Action  Rockstar Games  Rockstar North           9.7        19.39
# 2     PS2   Action  Rockstar Games  Rockstar North           9.6        16.15
# 3    X360   Action  Rockstar Games  Rockstar North           NaN        15.86
# 4     PS4  Shooter      Activision        Treyarch           8.1        15.09
#
# ...

# %%
df.drop('img', axis=1, inplace=True)

# %%
df.head()
# Out:
#                          title console    genre       publisher  \
# 0           Grand Theft Auto V     PS3   Action  Rockstar Games
# 1           Grand Theft Auto V     PS4   Action  Rockstar Games
# 2  Grand Theft Auto: Vice City     PS2   Action  Rockstar Games
# 3           Grand Theft Auto V    X360   Action  Rockstar Games
# 4    Call of Duty: Black Ops 3     PS4  Shooter      Activision
#
#         developer  critic_score  total_sales  na_sales  jp_sales  pal_sales  \
# 0  Rockstar North           9.4        20.32      6.37      0.99       9.85
# 1  Rockstar North           9.7        19.39      6.06      0.60       9.71
# 2  Rockstar North           9.6        16.15      8.41      0.47       5.49
# 3  Rockstar North           NaN        15.86      9.06      0.06       5.33
# 4        Treyarch           8.1        15.09      6.18      0.41       6.05
#
#    other_sales release_date last_update
# 0         3.12   17-09-2013         NaN
# 1         3.02   18-11-2014  03-01-2018
# ...

# %%
df.tail()
# Out:
#                                   title console         genre  \
# 64012                      Yoru, Tomosu     PS4  Visual Novel
# 64013                      Yoru, Tomosu      NS  Visual Novel
# 64014   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64015  Yurukill: The Calumniation Games     PS4  Visual Novel
# 64016  Yurukill: The Calumniation Games     PS5  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 64012  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64013  Nippon Ichi Software  Nippon Ichi Software           NaN          NaN
# 64014          Idea Factory               Otomate           NaN          NaN
# 64015               Unknown            G.rev Ltd.           NaN          NaN
# 64016               Unknown            G.rev Ltd.           NaN          NaN
#
#        na_sales  jp_sales  pal_sales  other_sales release_date last_update
# ...

# %%
df.describe()
# Out:
#        critic_score   total_sales      na_sales     jp_sales     pal_sales  \
# count   6678.000000  18922.000000  12637.000000  6726.000000  12824.000000
# mean       7.220440      0.349113      0.264740     0.102281      0.149472
# std        1.457066      0.807462      0.494787     0.168811      0.392653
# min        1.000000      0.000000      0.000000     0.000000      0.000000
# 25%        6.400000      0.030000      0.050000     0.020000      0.010000
# 50%        7.500000      0.120000      0.120000     0.040000      0.040000
# 75%        8.300000      0.340000      0.280000     0.120000      0.140000
# max       10.000000     20.320000      9.760000     2.130000      9.850000
#
#         other_sales
# count  15128.000000
# mean       0.043041
# std        0.126643
# min        0.000000
# 25%        0.000000
# 50%        0.010000
# 75%        0.030000
# max        3.120000

# %%
df['release_date']=pd.to_datetime(df['release_date'], dayfirst=True )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64017 entries, 0 to 64016
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         64017 non-null  object
#  1   console       64017 non-null  object
#  2   genre         64017 non-null  object
#  3   publisher     64017 non-null  object
#  4   developer     64000 non-null  object
#  5   critic_score  6678 non-null   float64
#  6   total_sales   18922 non-null  float64
#  7   na_sales      12637 non-null  float64
#  8   jp_sales      6726 non-null   float64
#  9   pal_sales     12824 non-null  float64
#  10  other_sales   15128 non-null  float64
#  11  release_date  56965 non-null  datetime64[ns]
#  12  last_update   17879 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(6)
# memory usage: 6.3+ MB

# %%
df.drop('last_update', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64017 entries, 0 to 64016
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         64017 non-null  object
#  1   console       64017 non-null  object
#  2   genre         64017 non-null  object
#  3   publisher     64017 non-null  object
#  4   developer     64000 non-null  object
#  5   critic_score  6678 non-null   float64
#  6   total_sales   18922 non-null  float64
#  7   na_sales      12637 non-null  float64
#  8   jp_sales      6726 non-null   float64
#  9   pal_sales     12824 non-null  float64
#  10  other_sales   15128 non-null  float64
#  11  release_date  56965 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), object(5)
# memory usage: 5.9+ MB

# %%
df.drop(['na_sales', 'jp_sales', 'pal_sales', 'other_sales'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64017 entries, 0 to 64016
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         64017 non-null  object
#  1   console       64017 non-null  object
#  2   genre         64017 non-null  object
#  3   publisher     64017 non-null  object
#  4   developer     64000 non-null  object
#  5   critic_score  6678 non-null   float64
#  6   total_sales   18922 non-null  float64
#  7   release_date  56965 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 3.9+ MB

# %%
df= df.drop_duplicates(subset='title' , keep='first')

# %%
df.head()
# Out:
#                             title console    genre       publisher  \
# 0              Grand Theft Auto V     PS3   Action  Rockstar Games
# 2     Grand Theft Auto: Vice City     PS2   Action  Rockstar Games
# 4       Call of Duty: Black Ops 3     PS4  Shooter      Activision
# 5  Call of Duty: Modern Warfare 3    X360  Shooter      Activision
# 6         Call of Duty: Black Ops    X360  Shooter      Activision
#
#         developer  critic_score  total_sales release_date
# 0  Rockstar North           9.4        20.32   2013-09-17
# 2  Rockstar North           9.6        16.15   2002-10-28
# 4        Treyarch           8.1        15.09   2015-11-06
# 5   Infinity Ward           8.7        14.82   2011-11-08
# 6        Treyarch           8.8        14.74   2010-11-09

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,9))

# %%
plt.scatter(df['total_sales'], df['critic_score'], color='blue')
plt.ylabel('Critic Score')
plt.xlabel('Total Sales (in millions)')
# Out:
# Text(0.5, 0, 'Total Sales (in millions)')

# %%
df = df[df['total_sales'] != 0]

# %%
plt.scatter(df['total_sales'], df['critic_score'], color='blue')
plt.ylabel('Critic Score')
plt.xlabel('Total Sales (in millions)')
# Out:
# Text(0.5, 0, 'Total Sales (in millions)')

# %%
df
# Out:
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 4             Call of Duty: Black Ops 3     PS4       Shooter
# 5        Call of Duty: Modern Warfare 3    X360       Shooter
# 6               Call of Duty: Black Ops    X360       Shooter
# ...                                 ...     ...           ...
# 64007                  Without Within 2      PC  Visual Novel
# 64008                  Without Within 3      PC  Visual Novel
# 64012                      Yoru, Tomosu     PS4  Visual Novel
# 64014   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64015  Yurukill: The Calumniation Games     PS4  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 0            Rockstar Games        Rockstar North           9.4        20.32
# ...

# %%
df.dropna(subset=('critic_score','total_sales'), inplace=True)

# %%
df
# Out:
#                                             title console         genre  \
# 0                              Grand Theft Auto V     PS3        Action
# 2                     Grand Theft Auto: Vice City     PS2        Action
# 4                       Call of Duty: Black Ops 3     PS4       Shooter
# 5                  Call of Duty: Modern Warfare 3    X360       Shooter
# 6                         Call of Duty: Black Ops    X360       Shooter
# ...                                           ...     ...           ...
# 17452  Neverwinter Nights 2: Mask of the Betrayer      PC  Role-Playing
# 17463                        Guild Wars: Factions      PC  Role-Playing
# 17493              Gurumin: A Monstrous Adventure     PSP  Role-Playing
# 17517        Neverwinter Nights 2: Storm of Zehir      PC  Role-Playing
# 17541                    Winx Club: Join the Club     PSP      Platform
#
#             publisher                 developer  critic_score  total_sales  \
# ...

# %%
plt.scatter(df['total_sales'], df['critic_score'], color='blue')
plt.ylabel('Critic Score')
plt.xlabel('Total Sales (in millions)')
# Out:
# Text(0.5, 0, 'Total Sales (in millions)')

# %%
df.reset_index()
# Out:
#       index                                       title console         genre  \
# 0         0                          Grand Theft Auto V     PS3        Action
# 1         2                 Grand Theft Auto: Vice City     PS2        Action
# 2         4                   Call of Duty: Black Ops 3     PS4       Shooter
# 3         5              Call of Duty: Modern Warfare 3    X360       Shooter
# 4         6                     Call of Duty: Black Ops    X360       Shooter
# ...     ...                                         ...     ...           ...
# 2392  17452  Neverwinter Nights 2: Mask of the Betrayer      PC  Role-Playing
# 2393  17463                        Guild Wars: Factions      PC  Role-Playing
# 2394  17493              Gurumin: A Monstrous Adventure     PSP  Role-Playing
# 2395  17517        Neverwinter Nights 2: Storm of Zehir      PC  Role-Playing
# 2396  17541                    Winx Club: Join the Club     PSP      Platform
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2397 entries, 0 to 17541
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         2397 non-null   object
#  1   console       2397 non-null   object
#  2   genre         2397 non-null   object
#  3   publisher     2397 non-null   object
#  4   developer     2397 non-null   object
#  5   critic_score  2397 non-null   float64
#  6   total_sales   2397 non-null   float64
#  7   release_date  2396 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 168.5+ KB

# %%
df.nunique()
# Out:
# title           2397
# console           27
# genre             19
# publisher        188
# developer        905
# critic_score      81
# total_sales      379
# release_date    1281
# dtype: int64

# %%
missing=df[df['release_date'].isnull()]

# %%
print(missing)
# Out:
#                           title console   genre publisher  \
# 11024  Zero: Tsukihami no Kamen     Wii  Action   Unknown
#
#                      developer  critic_score  total_sales release_date
# 11024  Grasshopper Manufacture           7.5         0.08          NaT

# %%
plt.scatter(df['critic_score'], df['total_sales'], color='blue')
plt.xlabel('Critic Score')
plt.ylabel('Total Sales (in millions)')
# Out:
# Text(0, 0.5, 'Total Sales (in millions)')

# %%
plt.scatter(df['critic_score'], np.log(df['total_sales']), color='blue', alpha=0.6)
plt.xlabel('Critic Score')
plt.ylabel('Total Sales (in millions)')
# Out:
# Text(0, 0.5, 'Total Sales (in millions)')

# %%
df['total_sales']=df['total_sales']*1000
plt.scatter(df['critic_score'], np.log(df['total_sales']),
            c=df['critic_score'], cmap='viridis', alpha=0.6)

# %% [markdown]
# ###### df.groupby("console")
